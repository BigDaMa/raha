# %% [markdown]
# # Raha

# %% [markdown]
# Welcome to Raha, a configuration-free error detection system!
# In this notebook, we will demonstrate this system. In particular, we will learn how we can simply detect data errors in a dataset via Raha.

# %% [markdown]
# ## 1. Loading Raha

# %% [markdown]
# We first need to import `dataset.py` and `raha.py`. We may need to install some Python 2.7 modules via `pip`.

# %%
import dataset
import raha

# %% [markdown]
# ## 2. Loading the Dataset

# %% [markdown]
# We next instantiate a dataset object. To this end, we just need to create a simple dictionary as follows and pass it to the `Dataset` class. `d` will be a dataset object.

# %%
dataset_dictionary = {
    "name": "toy",
    "path": "datasets/toy/dirty.csv"
}
d = dataset.Dataset(dataset_dictionary)
d.dataframe.head(6)
# Out:
#   ID     Lord       Kingdom
# 0  1  Aragorn  Minas Tirith
# 1  2   Sauron        Mordor
# 2  3  Gandalf
# 3  4  Saruman
# 4  5   Elrond           123
# 5  6  Theoden         Shire

# %% [markdown]
# ## 3. Instantiating the Raha Class

# %% [markdown]
# We then instantiate the Raha class.

# %%
application = raha.Raha()

# %% [markdown]
# ## 4. Running the Error Detection Strategies

# %% [markdown]
# We then run all the error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset. We suggest running this step offline.

# %%
application.strategy_profiler(d)
# Out:
# Running ["dboost", ["histogram", "0.7", "0.1"]] is done. Output size = 0
# Running ["dboost", ["histogram", "0.7", "0.2"]] is done. Output size = 1
# Running ["dboost", ["histogram", "0.7", "0.3"]] is done. Output size = 3
# Running ["dboost", ["histogram", "0.8", "0.1"]] is done. Output size = 0
# Running ["dboost", ["histogram", "0.8", "0.2"]] is done. Output size = 1
# Running ["dboost", ["histogram", "0.8", "0.3"]] is done. Output size = 1
# Running ["dboost", ["histogram", "0.9", "0.1"]] is done. Output size = 0
# Running ["dboost", ["histogram", "0.9", "0.2"]] is done. Output size = 0
# Running ["dboost", ["histogram", "0.9", "0.3"]] is done. Output size = 0
# Running ["dboost", ["gaussian", "1.0"]] is done. Output size = 4
# Running ["dboost", ["gaussian", "1.3"]] is done. Output size = 4
# Running ["dboost", ["gaussian", "1.5"]] is done. Output size = 4
# Running ["dboost", ["gaussian", "1.7"]] is done. Output size = 2
# Running ["dboost", ["gaussian", "2.0"]] is done. Output size = 1
# Running ["dboost", ["gaussian", "2.3"]] is done. Output size = 1
# Running ["dboost", ["gaussian", "2.5"]] is done. Output size = 0
# Running ["dboost", ["gaussian", "2.7"]] is done. Output size = 0
# Running ["dboost", ["gaussian", "3.0"]] is done. Output size = 0
# Running ["dboost", ["mixture", "3", "0.01"]] is done. Output size = 0
# Running ["dboost", ["mixture", "3", "0.10"]] is done. Output size = 0
# Running ["dboost", ["mixture", "3", "0.20"]] is done. Output size = 0
# Running ["dboost", ["mixture", "3", "0.30"]] is done. Output size = 0
# Running ["dboost", ["mixture", "5", "0.01"]] is done. Output size = 0
# Running ["dboost", ["mixture", "5", "0.10"]] is done. Output size = 0
# Running ["dboost", ["mixture", "5", "0.20"]] is done. Output size = 0
# Running ["dboost", ["mixture", "5", "0.30"]] is done. Output size = 0
# Running ["dboost", ["mixture", "8", "0.01"]] is done. Output size = 0
# Running ["dboost", ["mixture", "8", "0.10"]] is done. Output size = 0
# Running ["dboost", ["mixture", "8", "0.20"]] is done. Output size = 0
# Running ["dboost", ["mixture", "8", "0.30"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.7", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.7", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.7", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.8", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.8", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.8", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.9", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.9", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "3", "0.9", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.7", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.7", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.7", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.8", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.8", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.8", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.9", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.9", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "5", "0.9", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.7", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.7", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.7", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.8", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.8", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.8", "0.3"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.9", "0.1"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.9", "0.2"]] is done. Output size = 0
# Running ["dboost", ["partitionedhistogram", "8", "0.9", "0.3"]] is done. Output size = 0
# Running ["regex", [["ID", "[1]", "OM"]]] is done. Output size = 1
# Running ["regex", [["ID", "[3]", "OM"]]] is done. Output size = 1
# Running ["regex", [["ID", "[2]", "OM"]]] is done. Output size = 1
# Running ["regex", [["ID", "[5]", "OM"]]] is done. Output size = 1
# Running ["regex", [["ID", "[4]", "OM"]]] is done. Output size = 1
# Running ["regex", [["ID", "[6]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[A]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[a]", "OM"]]] is done. Output size = 4
# Running ["regex", [["Lord", "[E]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[G]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[g]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[f]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[h]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[m]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[l]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Lord", "[o]", "OM"]]] is done. Output size = 4
# Running ["regex", [["Lord", "[n]", "OM"]]] is done. Output size = 6
# Running ["regex", [["Lord", "[S]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Lord", "[r]", "OM"]]] is done. Output size = 4
# Running ["regex", [["Lord", "[u]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Lord", "[T]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[e]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Lord", "[d]", "OM"]]] is done. Output size = 3
# Running ["regex", [["Kingdom", "[a]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[ ]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[e]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[d]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[i]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Kingdom", "[h]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Kingdom", "[M]", "OM"]]] is done. Output size = 2
# Running ["regex", [["Kingdom", "[3]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[o]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[n]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[1]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[s]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[r]", "OM"]]] is done. Output size = 3
# Running ["regex", [["Kingdom", "[T]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[2]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[S]", "OM"]]] is done. Output size = 1
# Running ["regex", [["Kingdom", "[t]", "OM"]]] is done. Output size = 1
# Running ["fd_checker", [["ID", "Lord"]]] is done. Output size = 0
# Running ["fd_checker", [["ID", "Kingdom"]]] is done. Output size = 0
# Running ["fd_checker", [["Lord", "ID"]]] is done. Output size = 0
# Running ["fd_checker", [["Lord", "Kingdom"]]] is done. Output size = 0
# Running ["fd_checker", [["Kingdom", "ID"]]] is done. Output size = 4
# Running ["fd_checker", [["Kingdom", "Lord"]]] is done. Output size = 4
# Running ["katara", [" Commercials .rel.txt"]] is done. Output size = 0
# Running ["katara", ["abbreviation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["absMagnitude.rel.txt"]] is done. Output size = 4
# Running ["katara", ["academicAdvisors.rel.txt"]] is done. Output size = 0
# Running ["katara", ["access.rel.txt"]] is done. Output size = 0
# Running ["katara", ["acreage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["act.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ada.rel.txt"]] is done. Output size = 0
# Running ["katara", ["added.rel.txt"]] is done. Output size = 0
# Running ["katara", ["address.rel.txt"]] is done. Output size = 4
# Running ["katara", ["addresses.rel.txt"]] is done. Output size = 0
# Running ["katara", ["adjacentcomuni.rel.txt"]] is done. Output size = 0
# Running ["katara", ["administrator.rel.txt"]] is done. Output size = 0
# Running ["katara", ["aEngineer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["affiliates.rel.txt"]] is done. Output size = 0
# Running ["katara", ["affiliation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["notes.rel.txt"]] is done. Output size = 0
# Running ["katara", ["notrack.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nrhpType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nssdcId.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ntsawards.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numAttorneys.rel.txt"]] is done. Output size = 0
# Running ["katara", ["number.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberBuilt.rel.txt"]] is done. Output size = 2
# Running ["katara", ["numberbuilt.rel.txt"]] is done. Output size = 3
# Running ["katara", ["numberOfFilms.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberOfPupils.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberOfRestaurants.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberOfRooms.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberOfStaff.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numberOfSuites.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numEmployees.rel.txt"]] is done. Output size = 0
# Running ["katara", ["numemployees.rel.txt"]] is done. Output size = 0
# Running ["katara", ["design.rel.txt"]] is done. Output size = 0
# Running ["katara", ["designatedOther1Name.rel.txt"]] is done. Output size = 0
# Running ["katara", ["designatedOther2Name.rel.txt"]] is done. Output size = 0
# Running ["katara", ["designer.rel.txt"]] is done. Output size = 3
# Running ["katara", ["destinations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["destructionDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["developedFrom.rel.txt"]] is done. Output size = 3
# Running ["katara", ["developer.rel.txt"]] is done. Output size = 4
# Running ["katara", ["dewey.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dialCode.rel.txt"]] is done. Output size = 0
# Running ["katara", ["diameter.rel.txt"]] is done. Output size = 0
# Running ["katara", ["died.rel.txt"]] is done. Output size = 0
# Running ["katara", ["digital.rel.txt"]] is done. Output size = 0
# Running ["katara", ["directionA.rel.txt"]] is done. Output size = 0
# Running ["katara", ["directionB.rel.txt"]] is done. Output size = 0
# Running ["katara", ["director.rel.txt"]] is done. Output size = 4
# Running ["katara", ["directors.rel.txt"]] is done. Output size = 0
# Running ["katara", ["disbanded.rel.txt"]] is done. Output size = 0
# Running ["katara", ["discharge.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r6LengthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r6Number.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r6Surface.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r7LengthF.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r7LengthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r7Number.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r7Surface.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r8LengthF.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r8LengthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r8Number.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r8Surface.rel.txt"]] is done. Output size = 0
# Running ["katara", ["race.rel.txt"]] is done. Output size = 0
# Running ["katara", ["races.rel.txt"]] is done. Output size = 0
# Running ["katara", ["railcode.rel.txt"]] is done. Output size = 0
# Running ["katara", ["railroadName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["range.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rank.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ranking.rel.txt"]] is done. Output size = 0
# Running ["katara", ["affiliations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alliance.rel.txt"]] is done. Output size = 0
# Running ["katara", ["animal.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaSqMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["artist.rel.txt"]] is done. Output size = 3
# Running ["katara", ["authority.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bases.rel.txt"]] is done. Output size = 0
# Running ["katara", ["birthplace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["branch.rel.txt"]] is done. Output size = 4
# Running ["katara", ["b\u00fcrgermeister.rel.txt"]] is done. Output size = 0
# Running ["katara", ["capitalElevation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["category.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champions.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chief1Name.rel.txt"]] is done. Output size = 0
# Running ["katara", ["cities.rel.txt"]] is done. Output size = 0
# Running ["katara", ["club.rel.txt"]] is done. Output size = 0
# Running ["katara", ["commandant.rel.txt"]] is done. Output size = 0
# Running ["katara", ["conflict.rel.txt"]] is done. Output size = 0
# Running ["katara", ["cornishName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["curator.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pictureFormat.rel.txt"]] is done. Output size = 4
# Running ["katara", ["pierswater.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pinyinchinesename.rel.txt"]] is done. Output size = 0
# Running ["katara", ["place.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeOfBirth.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeofbirth.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeOfBurial.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeofburial.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeOfDeath.rel.txt"]] is done. Output size = 0
# Running ["katara", ["placeofdeath.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plant.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantAnnualGen.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantCapacity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantCommission.rel.txt"]] is done. Output size = 0
# Running ["katara", ["planted.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantOperator.rel.txt"]] is done. Output size = 0
# Running ["katara", ["branchfrom.rel.txt"]] is done. Output size = 0
# Running ["katara", ["branchOf.rel.txt"]] is done. Output size = 0
# Running ["katara", ["branchto.rel.txt"]] is done. Output size = 0
# Running ["katara", ["brand.rel.txt"]] is done. Output size = 0
# Running ["katara", ["branding.rel.txt"]] is done. Output size = 0
# Running ["katara", ["breeder.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bridgeName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["broadcastArea.rel.txt"]] is done. Output size = 0
# Running ["katara", ["brokeGround.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bronze.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bSide.rel.txt"]] is done. Output size = 4
# Running ["katara", ["budget.rel.txt"]] is done. Output size = 0
# Running ["katara", ["builddate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["builder.rel.txt"]] is done. Output size = 0
# Running ["katara", ["building.rel.txt"]] is done. Output size = 0
# Running ["katara", ["buildingName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["buildingType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["built.rel.txt"]] is done. Output size = 0
# Running ["katara", ["builtBy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bundesland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["burialPlace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bust.rel.txt"]] is done. Output size = 0
# Running ["katara", ["landkreis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lanes.rel.txt"]] is done. Output size = 0
# Running ["katara", ["langs.rel.txt"]] is done. Output size = 0
# Running ["katara", ["language.rel.txt"]] is done. Output size = 1
# Running ["katara", ["languages.rel.txt"]] is done. Output size = 0
# Running ["katara", ["largestCity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["largestcity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["largestCityWl.rel.txt"]] is done. Output size = 0
# Running ["katara", ["largestSettlement.rel.txt"]] is done. Output size = 0
# Running ["katara", ["largestwin.rel.txt"]] is done. Output size = 0
# Running ["katara", ["last.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lastAired.rel.txt"]] is done. Output size = 4
# Running ["katara", ["lastAlbum.rel.txt"]] is done. Output size = 4
# Running ["katara", ["lastDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lastdate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lastElection.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stateAssembly.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stateDelegate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stateHouse.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stateLegislature.rel.txt"]] is done. Output size = 0
# Running ["katara", ["states.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stateSenate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["station.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stationBranding.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stationLogo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stations.rel.txt"]] is done. Output size = 4
# Running ["katara", ["stationSlogan.rel.txt"]] is done. Output size = 0
# Running ["katara", ["status.rel.txt"]] is done. Output size = 0
# Running ["katara", ["statusSystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["statyear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stock.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stops.rel.txt"]] is done. Output size = 0
# Running ["katara", ["streetAddress.rel.txt"]] is done. Output size = 0
# Running ["katara", ["streetaddress.rel.txt"]] is done. Output size = 0
# Running ["katara", ["strength.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stroke.rel.txt"]] is done. Output size = 0
# Running ["katara", ["structuralEngineer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["structuralSystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["foundedYear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["founder.rel.txt"]] is done. Output size = 0
# Running ["katara", ["founders.rel.txt"]] is done. Output size = 0
# Running ["katara", ["frazioni.rel.txt"]] is done. Output size = 0
# Running ["katara", ["frequency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["frequentlyUpdated.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fromAlbum.rel.txt"]] is done. Output size = 4
# Running ["katara", ["frozen.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fuelCapacity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fuelcon.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fuelsystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fueltype.rel.txt"]] is done. Output size = 4
# Running ["katara", ["fullName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fullname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["function.rel.txt"]] is done. Output size = 0
# Running ["katara", ["funding.rel.txt"]] is done. Output size = 0
# Running ["katara", ["fusiongenres.rel.txt"]] is done. Output size = 0
# Running ["katara", ["g.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gaelicName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["games.rel.txt"]] is done. Output size = 0
# Running ["katara", ["garrison.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gasChambers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gauge.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gdp.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gemeindeverwaltungsverband.rel.txt"]] is done. Output size = 0
# Running ["katara", ["gender.rel.txt"]] is done. Output size = 0
# Running ["katara", ["championships.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champmd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champms.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champs.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champwd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champwins.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champws.rel.txt"]] is done. Output size = 0
# Running ["katara", ["champxd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chancellor.rel.txt"]] is done. Output size = 0
# Running ["katara", ["channel.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chaplain.rel.txt"]] is done. Output size = 0
# Running ["katara", ["characterName.rel.txt"]] is done. Output size = 4
# Running ["katara", ["characters.rel.txt"]] is done. Output size = 0
# Running ["katara", ["charingxDistanceMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chebi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chef.rel.txt"]] is done. Output size = 0
# Running ["katara", ["short.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shortname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shot.rel.txt"]] is done. Output size = 0
# Running ["katara", ["show.rel.txt"]] is done. Output size = 0
# Running ["katara", ["showName.rel.txt"]] is done. Output size = 4
# Running ["katara", ["sign.rel.txt"]] is done. Output size = 0
# Running ["katara", ["signature.rel.txt"]] is done. Output size = 0
# Running ["katara", ["significance.rel.txt"]] is done. Output size = 0
# Running ["katara", ["significantAwards.rel.txt"]] is done. Output size = 0
# Running ["katara", ["significantBuildings.rel.txt"]] is done. Output size = 0
# Running ["katara", ["significantDesign.rel.txt"]] is done. Output size = 0
# Running ["katara", ["significantProjects.rel.txt"]] is done. Output size = 0
# Running ["katara", ["silver.rel.txt"]] is done. Output size = 0
# Running ["katara", ["similar.rel.txt"]] is done. Output size = 0
# Running ["katara", ["similarDish.rel.txt"]] is done. Output size = 0
# Running ["katara", ["simpchinesename.rel.txt"]] is done. Output size = 0
# Running ["katara", ["uniprot.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unit.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unitaryNorthernIreland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unitaryScotland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unitaryWales.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unitCost.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unitName.rel.txt"]] is done. Output size = 4
# Running ["katara", ["university.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedClassis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedDivisio.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedFamilia.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedGenus.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedInfraclassis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedOrdo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedPhylum.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedRegnum.rel.txt"]] is done. Output size = 0
# Running ["katara", ["unrankedSubclassis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["upperAge.rel.txt"]] is done. Output size = 0
# Running ["katara", ["url.rel.txt"]] is done. Output size = 4
# Running ["katara", ["usage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["used.rel.txt"]] is done. Output size = 0
# Running ["katara", ["usingCountries.rel.txt"]] is done. Output size = 0
# Running ["katara", ["utcOffset.rel.txt"]] is done. Output size = 0
# Running ["katara", ["utcOffset1Dst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["utcOffset2Dst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["utcOffsetDst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["v.rel.txt"]] is done. Output size = 0
# Running ["katara", ["valvetrain.rel.txt"]] is done. Output size = 0
# Running ["katara", ["merged.rel.txt"]] is done. Output size = 0
# Running ["katara", ["meshid.rel.txt"]] is done. Output size = 0
# Running ["katara", ["meshname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["meshnumber.rel.txt"]] is done. Output size = 0
# Running ["katara", ["metropolitanBorough.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mgiid.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mgrtitle.rel.txt"]] is done. Output size = 0
# Running ["katara", ["microphylum.rel.txt"]] is done. Output size = 0
# Running ["katara", ["minister1Name.rel.txt"]] is done. Output size = 0
# Running ["katara", ["minTemp.rel.txt"]] is done. Output size = 4
# Running ["katara", ["mintime.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mission.rel.txt"]] is done. Output size = 0
# Running ["katara", ["missions.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mmEnsembl.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mmEntrezgene.rel.txt"]] is done. Output size = 0
# Running ["katara", ["mmGenlocChr.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaSqmi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaTotal.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaTotalAcre.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaTotalHa.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaTotalKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaTotalSqMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaUrbanKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaUrbanSqMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaWaterKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaWaterPercent.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaWaterPercentage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["areaWaterSqMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["arena.rel.txt"]] is done. Output size = 0
# Running ["katara", ["arguedate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["arm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["arname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["arrondissement.rel.txt"]] is done. Output size = 0
# Running ["katara", ["art.rel.txt"]] is done. Output size = 0
# Running ["katara", ["artery.rel.txt"]] is done. Output size = 0
# Running ["katara", ["operatingSystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["operatingsystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["operationWillStart.rel.txt"]] is done. Output size = 0
# Running ["katara", ["operator.rel.txt"]] is done. Output size = 3
# Running ["katara", ["opponent.rel.txt"]] is done. Output size = 0
# Running ["katara", ["opponents.rel.txt"]] is done. Output size = 0
# Running ["katara", ["orbital.rel.txt"]] is done. Output size = 0
# Running ["katara", ["orbits.rel.txt"]] is done. Output size = 0
# Running ["katara", ["order.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ordo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["org.rel.txt"]] is done. Output size = 0
# Running ["katara", ["organizationName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["origin.rel.txt"]] is done. Output size = 7
# Running ["katara", ["originalUse.rel.txt"]] is done. Output size = 0
# Running ["katara", ["origLang.rel.txt"]] is done. Output size = 0
# Running ["katara", ["orogeny.rel.txt"]] is done. Output size = 0
# Running ["katara", ["os.rel.txt"]] is done. Output size = 0
# Running ["katara", ["products.rel.txt"]] is done. Output size = 0
# Running ["katara", ["profession.rel.txt"]] is done. Output size = 0
# Running ["katara", ["professional.rel.txt"]] is done. Output size = 0
# Running ["katara", ["progLanguage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["programCost.rel.txt"]] is done. Output size = 0
# Running ["katara", ["programmingLanguage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prominence.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prominenceFt.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prominenceM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["promotion.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prospectLeague.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prospectTeam.rel.txt"]] is done. Output size = 0
# Running ["katara", ["protein.rel.txt"]] is done. Output size = 0
# Running ["katara", ["province.rel.txt"]] is done. Output size = 0
# Running ["katara", ["provinces.rel.txt"]] is done. Output size = 0
# Running ["katara", ["provost.rel.txt"]] is done. Output size = 0
# Running ["katara", ["prowins.rel.txt"]] is done. Output size = 0
# Running ["katara", ["psAnnualGeneration.rel.txt"]] is done. Output size = 0
# Running ["katara", ["psElectricalCapacity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["psElectricalCapFac.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pseudonym.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pubchem.rel.txt"]] is done. Output size = 4
# Running ["katara", ["pubDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["public.rel.txt"]] is done. Output size = 0
# Running ["katara", ["published.rel.txt"]] is done. Output size = 4
# Running ["katara", ["publisher.rel.txt"]] is done. Output size = 1
# Running ["katara", ["publisherEn.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pupils.rel.txt"]] is done. Output size = 0
# Running ["katara", ["purpose.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r1LengthF.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r1LengthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["r1Number.rel.txt"]] is done. Output size = 0
# Running ["katara", ["congress.rel.txt"]] is done. Output size = 0
# Running ["katara", ["conscription.rel.txt"]] is done. Output size = 0
# Running ["katara", ["const.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constituency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constituencyAm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constituencyManxParliament.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constituencyMp.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constructed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["construction.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constructionBegan.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constructionCost.rel.txt"]] is done. Output size = 0
# Running ["katara", ["constructionStartDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["contract.rel.txt"]] is done. Output size = 0
# Running ["katara", ["conventionalLongName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coolingsystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coordinator.rel.txt"]] is done. Output size = 0
# Running ["katara", ["engineer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["enginetype.rel.txt"]] is done. Output size = 3
# Running ["katara", ["englishPubDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["enName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["enrollment.rel.txt"]] is done. Output size = 0
# Running ["katara", ["enrolment.rel.txt"]] is done. Output size = 0
# Running ["katara", ["enthroned.rel.txt"]] is done. Output size = 0
# Running ["katara", ["entrezgene.rel.txt"]] is done. Output size = 0
# Running ["katara", ["episode.rel.txt"]] is done. Output size = 0
# Running ["katara", ["epoch.rel.txt"]] is done. Output size = 4
# Running ["katara", ["equipment.rel.txt"]] is done. Output size = 0
# Running ["katara", ["equity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["era.rel.txt"]] is done. Output size = 0
# Running ["katara", ["erp.rel.txt"]] is done. Output size = 0
# Running ["katara", ["escapeVelocity.rel.txt"]] is done. Output size = 4
# Running ["katara", ["espn.rel.txt"]] is done. Output size = 0
# Running ["katara", ["est.rel.txt"]] is done. Output size = 0
# Running ["katara", ["established.rel.txt"]] is done. Output size = 0
# Running ["katara", ["establishedDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["estCompletion.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ethnic.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ethnicGroups.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ethnicGroupsYear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ethnicity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["etymology.rel.txt"]] is done. Output size = 0
# Running ["katara", ["europarl.rel.txt"]] is done. Output size = 0
# Running ["katara", ["european.rel.txt"]] is done. Output size = 0
# Running ["katara", ["restoredate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["result.rel.txt"]] is done. Output size = 0
# Running ["katara", ["retired.rel.txt"]] is done. Output size = 0
# Running ["katara", ["retiredate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["retirement.rel.txt"]] is done. Output size = 0
# Running ["katara", ["revenue.rel.txt"]] is done. Output size = 0
# Running ["katara", ["reviews.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rHead.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rHeadLabel.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ridername.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ridership.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rival.rel.txt"]] is done. Output size = 0
# Running ["katara", ["river.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rivers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["rkdartists.rel.txt"]] is done. Output size = 0
# Running ["katara", ["roadName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["roads.rel.txt"]] is done. Output size = 0
# Running ["katara", ["roadType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timeshiftNames.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timeZone.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timezone.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timezone1Dst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timezone2Dst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["timezoneDst.rel.txt"]] is done. Output size = 0
# Running ["katara", ["title.rel.txt"]] is done. Output size = 6
# Running ["katara", ["titleOrig.rel.txt"]] is done. Output size = 0
# Running ["katara", ["titles.rel.txt"]] is done. Output size = 0
# Running ["katara", ["tlaunches.rel.txt"]] is done. Output size = 0
# Running ["katara", ["toll.rel.txt"]] is done. Output size = 0
# Running ["katara", ["topElevation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["topo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["topscorer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["topSpeed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["torque.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsEnsembl.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsEntrezgene.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsGenlocChr.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsGenlocDb.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsGenlocEnd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsGenlocStart.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsRefseqmrna.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsRefseqprotein.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hsUniprot.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hubs.rel.txt"]] is done. Output size = 0
# Running ["katara", ["hybrid.rel.txt"]] is done. Output size = 0
# Running ["katara", ["h\u00f6he.rel.txt"]] is done. Output size = 0
# Running ["katara", ["iata.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ibdbId.rel.txt"]] is done. Output size = 0
# Running ["katara", ["icao.rel.txt"]] is done. Output size = 0
# Running ["katara", ["icd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["variantsWithTheirOwnArticles.rel.txt"]] is done. Output size = 0
# Running ["katara", ["variations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["varietals.rel.txt"]] is done. Output size = 0
# Running ["katara", ["vehicles.rel.txt"]] is done. Output size = 0
# Running ["katara", ["vein.rel.txt"]] is done. Output size = 0
# Running ["katara", ["veneratedIn.rel.txt"]] is done. Output size = 0
# Running ["katara", ["venue.rel.txt"]] is done. Output size = 0
# Running ["katara", ["verbandsgemeinde.rel.txt"]] is done. Output size = 0
# Running ["katara", ["verwaltungsgemeinschaft.rel.txt"]] is done. Output size = 0
# Running ["katara", ["verwaltungsverband.rel.txt"]] is done. Output size = 0
# Running ["katara", ["viaf.rel.txt"]] is done. Output size = 0
# Running ["katara", ["viceChancellor.rel.txt"]] is done. Output size = 0
# Running ["katara", ["vicePresident.rel.txt"]] is done. Output size = 0
# Running ["katara", ["vicepresident.rel.txt"]] is done. Output size = 0
# Running ["katara", ["viceprimeminister.rel.txt"]] is done. Output size = 0
# Running ["katara", ["viceprincipal.rel.txt"]] is done. Output size = 0
# Running ["katara", ["viceprincipalLabel.rel.txt"]] is done. Output size = 0
# Running ["katara", ["vineyards.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalAnthem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalcaps.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalCuisine.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalgoals.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationality.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalMotto.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalOrigin.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalRanking.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalteam.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationalyears.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nationsParticipating.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nativeBuildingName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nativeName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nativename.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nativenameA.rel.txt"]] is done. Output size = 0
# Running ["katara", ["nativeNameLang.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leoPayload.rel.txt"]] is done. Output size = 0
# Running ["katara", ["letwins.rel.txt"]] is done. Output size = 0
# Running ["katara", ["levels.rel.txt"]] is done. Output size = 0
# Running ["katara", ["liberatedBy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["libraryName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["licence.rel.txt"]] is done. Output size = 0
# Running ["katara", ["license.rel.txt"]] is done. Output size = 0
# Running ["katara", ["licensee.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lid.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lieutenancyEngland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lieutenancyNorthernIreland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lieutenancyScotland.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lieutenancyWales.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lieutenant.rel.txt"]] is done. Output size = 0
# Running ["katara", ["line.rel.txt"]] is done. Output size = 0
# Running ["katara", ["linelength.rel.txt"]] is done. Output size = 0
# Running ["katara", ["linelengthKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["linelengthMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lines.rel.txt"]] is done. Output size = 0
# Running ["katara", ["link.rel.txt"]] is done. Output size = 0
# Running ["katara", ["load.rel.txt"]] is done. Output size = 0
# Running ["katara", ["local.rel.txt"]] is done. Output size = 0
# Running ["katara", ["specialist.rel.txt"]] is done. Output size = 0
# Running ["katara", ["species.rel.txt"]] is done. Output size = 0
# Running ["katara", ["speciesComplex.rel.txt"]] is done. Output size = 0
# Running ["katara", ["speciesGroup.rel.txt"]] is done. Output size = 0
# Running ["katara", ["speciesSubgroup.rel.txt"]] is done. Output size = 0
# Running ["katara", ["speed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["speedMph.rel.txt"]] is done. Output size = 0
# Running ["katara", ["spike.rel.txt"]] is done. Output size = 0
# Running ["katara", ["split.rel.txt"]] is done. Output size = 0
# Running ["katara", ["spokesperson.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sport.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sportCountry.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sports.rel.txt"]] is done. Output size = 0
# Running ["katara", ["spouse.rel.txt"]] is done. Output size = 4
# Running ["katara", ["sr.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stadium.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stadiumName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["staff.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stages.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stand.rel.txt"]] is done. Output size = 0
# Running ["katara", ["starring.rel.txt"]] is done. Output size = 4
# Running ["katara", ["start.rel.txt"]] is done. Output size = 4
# Running ["katara", ["startDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["starting.rel.txt"]] is done. Output size = 0
# Running ["katara", ["startYear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stat1label.rel.txt"]] is done. Output size = 0
# Running ["katara", ["stat1value.rel.txt"]] is done. Output size = 0
# Running ["katara", ["almaMater.rel.txt"]] is done. Output size = 4
# Running ["katara", ["almaMatter.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alongside.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alterEgo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alternateName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alternativeSpelling.rel.txt"]] is done. Output size = 0
# Running ["katara", ["altitude.rel.txt"]] is done. Output size = 0
# Running ["katara", ["altName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["altNames.rel.txt"]] is done. Output size = 4
# Running ["katara", ["altoffsp.rel.txt"]] is done. Output size = 0
# Running ["katara", ["altsymbols.rel.txt"]] is done. Output size = 0
# Running ["katara", ["altunosp.rel.txt"]] is done. Output size = 0
# Running ["katara", ["alumni.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ambassadorFrom.rel.txt"]] is done. Output size = 0
# Running ["katara", ["amt.rel.txt"]] is done. Output size = 0
# Running ["katara", ["analog.rel.txt"]] is done. Output size = 0
# Running ["katara", ["b\u00fcrgermeistertitel.rel.txt"]] is done. Output size = 0
# Running ["katara", ["c.rel.txt"]] is done. Output size = 0
# Running ["katara", ["cabinet.rel.txt"]] is done. Output size = 0
# Running ["katara", ["callLetters.rel.txt"]] is done. Output size = 0
# Running ["katara", ["callsign.rel.txt"]] is done. Output size = 0
# Running ["katara", ["callsignMeaning.rel.txt"]] is done. Output size = 0
# Running ["katara", ["callsigns.rel.txt"]] is done. Output size = 0
# Running ["katara", ["calories.rel.txt"]] is done. Output size = 0
# Running ["katara", ["campus.rel.txt"]] is done. Output size = 0
# Running ["katara", ["campusSize.rel.txt"]] is done. Output size = 0
# Running ["katara", ["campusType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["canonizedBy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["canonizedDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["canonizedPlace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["canton.rel.txt"]] is done. Output size = 0
# Running ["katara", ["capacity.rel.txt"]] is done. Output size = 4
# Running ["katara", ["capital.rel.txt"]] is done. Output size = 0
# Running ["katara", ["capitalCountry.rel.txt"]] is done. Output size = 0
# Running ["katara", ["clubname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["clubnumber.rel.txt"]] is done. Output size = 0
# Running ["katara", ["clubs.rel.txt"]] is done. Output size = 0
# Running ["katara", ["clyears.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coach.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coachingRecords.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coachTeams.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coachyear1end.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coachyear1start.rel.txt"]] is done. Output size = 0
# Running ["katara", ["code.rel.txt"]] is done. Output size = 0
# Running ["katara", ["coden.rel.txt"]] is done. Output size = 0
# Running ["katara", ["collapsed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["collection.rel.txt"]] is done. Output size = 0
# Running ["katara", ["college.rel.txt"]] is done. Output size = 0
# Running ["katara", ["color.rel.txt"]] is done. Output size = 0
# Running ["katara", ["colors.rel.txt"]] is done. Output size = 0
# Running ["katara", ["colour.rel.txt"]] is done. Output size = 0
# Running ["katara", ["colours.rel.txt"]] is done. Output size = 0
# Running ["katara", ["combatant.rel.txt"]] is done. Output size = 0
# Running ["katara", ["basinCountries.rel.txt"]] is done. Output size = 0
# Running ["katara", ["basis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bats.rel.txt"]] is done. Output size = 0
# Running ["katara", ["battleHonours.rel.txt"]] is done. Output size = 0
# Running ["katara", ["battles.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bayName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beatifiedBy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beatifiedDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beatifiedPlace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beds.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beganOperation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["begin.rel.txt"]] is done. Output size = 0
# Running ["katara", ["belfastDistance.rel.txt"]] is done. Output size = 0
# Running ["katara", ["belfastDistanceKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["belfastDistanceMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["beltwayCity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bestFinish.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bezirk.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bibsys.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bicycle.rel.txt"]] is done. Output size = 0
# Running ["katara", ["billed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["binomial.rel.txt"]] is done. Output size = 0
# Running ["katara", ["binomialAuthority.rel.txt"]] is done. Output size = 0
# Running ["katara", ["bioavailability.rel.txt"]] is done. Output size = 0
# Running ["katara", ["biome.rel.txt"]] is done. Output size = 0
# Running ["katara", ["birth.rel.txt"]] is done. Output size = 0
# Running ["katara", ["birthDate.rel.txt"]] is done. Output size = 4
# Running ["katara", ["birthdate.rel.txt"]] is done. Output size = 0
# ...
# Running ["katara", ["shipNickname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipOperator.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipOrdered.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipOriginalCost.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipOutOfService.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipOwner.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipPower.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipRecommissioned.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipSpeed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipStatus.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shipType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shireCounty.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shireDistrict.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shoeSize.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shoots.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shoppingMallName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["shore.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lccn.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lea.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leader.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leaderName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leaderParty.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leaderTitle.rel.txt"]] is done. Output size = 0
# Running ["katara", ["league.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leagueResult.rel.txt"]] is done. Output size = 0
# Running ["katara", ["leagues.rel.txt"]] is done. Output size = 0
# Running ["katara", ["legislature.rel.txt"]] is done. Output size = 0
# Running ["katara", ["length.rel.txt"]] is done. Output size = 4
# Running ["katara", ["lengthFt.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lengthImperial.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lengthKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lengthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["lengthMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chiefeditor.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child1Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child2Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child3Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child4Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child5Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child6Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child7Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child8Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["child9Agency.rel.txt"]] is done. Output size = 0
# Running ["katara", ["childLeft.rel.txt"]] is done. Output size = 0
# Running ["katara", ["children.rel.txt"]] is done. Output size = 0
# Running ["katara", ["childRight.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chinesename.rel.txt"]] is done. Output size = 0
# Running ["katara", ["choreographer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chorus.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chromosome.rel.txt"]] is done. Output size = 0
# Running ["katara", ["chrtitle.rel.txt"]] is done. Output size = 0
# Running ["katara", ["churchName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["cinematography.rel.txt"]] is done. Output size = 8
# Running ["katara", ["circulation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["circulationYear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["partof.rel.txt"]] is done. Output size = 0
# Running ["katara", ["party.rel.txt"]] is done. Output size = 0
# Running ["katara", ["partyElection.rel.txt"]] is done. Output size = 0
# Running ["katara", ["parvordo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["passengers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["passPercent.rel.txt"]] is done. Output size = 0
# Running ["katara", ["passSystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["passYear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pastMembers.rel.txt"]] is done. Output size = 4
# Running ["katara", ["pastmembers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pastor.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pastschools.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pastteams.rel.txt"]] is done. Output size = 0
# Running ["katara", ["patron.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pdb.rel.txt"]] is done. Output size = 0
# Running ["katara", ["peerReviewed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["penname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["percentWater.rel.txt"]] is done. Output size = 0
# Running ["katara", ["periapsis.rel.txt"]] is done. Output size = 0
# Running ["katara", ["periastron.rel.txt"]] is done. Output size = 0
# Running ["katara", ["perihelion.rel.txt"]] is done. Output size = 4
# Running ["katara", ["period.rel.txt"]] is done. Output size = 4
# Running ["katara", ["pgawins.rel.txt"]] is done. Output size = 0
# Running ["katara", ["photo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["photographer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locale.rel.txt"]] is done. Output size = 0
# Running ["katara", ["localName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["localnames.rel.txt"]] is done. Output size = 0
# Running ["katara", ["location.rel.txt"]] is done. Output size = 7
# Running ["katara", ["locationCity.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locationCountry.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locationMap.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locationTown.rel.txt"]] is done. Output size = 0
# Running ["katara", ["locussupplementarydata.rel.txt"]] is done. Output size = 0
# Running ["katara", ["logo.rel.txt"]] is done. Output size = 0
# Running ["katara", ["logofile.rel.txt"]] is done. Output size = 0
# Running ["katara", ["logoFilename.rel.txt"]] is done. Output size = 0
# Running ["katara", ["logoSize.rel.txt"]] is done. Output size = 0
# Running ["katara", ["londonBorough.rel.txt"]] is done. Output size = 0
# Running ["katara", ["officialname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["officials.rel.txt"]] is done. Output size = 0
# Running ["katara", ["officialSite.rel.txt"]] is done. Output size = 0
# Running ["katara", ["offspring.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oilsystem.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oldcode.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oldname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oldNames.rel.txt"]] is done. Output size = 0
# Running ["katara", ["olympicteams.rel.txt"]] is done. Output size = 0
# Running ["katara", ["omim.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oName.rel.txt"]] is done. Output size = 0
# Running ["katara", ["oneday.rel.txt"]] is done. Output size = 0
# Running ["katara", ["open.rel.txt"]] is done. Output size = 4
# Running ["katara", ["openaccess.rel.txt"]] is done. Output size = 0
# Running ["katara", ["opened.rel.txt"]] is done. Output size = 0
# Running ["katara", ["opening.rel.txt"]] is done. Output size = 0
# Running ["katara", ["openingDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["opentheme.rel.txt"]] is done. Output size = 0
# Running ["katara", ["operatedBy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["temperatureHighC.rel.txt"]] is done. Output size = 0
# Running ["katara", ["temperatureLow.rel.txt"]] is done. Output size = 0
# Running ["katara", ["temperatureLowC.rel.txt"]] is done. Output size = 0
# Running ["katara", ["tenant.rel.txt"]] is done. Output size = 0
# Running ["katara", ["tenants.rel.txt"]] is done. Output size = 0
# Running ["katara", ["termEnd.rel.txt"]] is done. Output size = 0
# Running ["katara", ["terminusA.rel.txt"]] is done. Output size = 0
# Running ["katara", ["terminusB.rel.txt"]] is done. Output size = 0
# Running ["katara", ["termStart.rel.txt"]] is done. Output size = 0
# Running ["katara", ["territory.rel.txt"]] is done. Output size = 0
# Running ["katara", ["testaverage.rel.txt"]] is done. Output size = 0
# Running ["katara", ["themeMusicComposer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["thirdCountry.rel.txt"]] is done. Output size = 0
# Running ["katara", ["thirdDriver.rel.txt"]] is done. Output size = 0
# Running ["katara", ["thirdTeam.rel.txt"]] is done. Output size = 0
# Running ["katara", ["through.rel.txt"]] is done. Output size = 0
# Running ["katara", ["throws.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sire.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sisterCollege.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sisterNames.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sisterNewspapers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sisterStations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["site.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sites.rel.txt"]] is done. Output size = 0
# Running ["katara", ["sixthFormStudents.rel.txt"]] is done. Output size = 0
# Running ["katara", ["size.rel.txt"]] is done. Output size = 0
# Running ["katara", ["skiableArea.rel.txt"]] is done. Output size = 0
# Running ["katara", ["slogan.rel.txt"]] is done. Output size = 0
# Running ["katara", ["smartcardname.rel.txt"]] is done. Output size = 0
# Running ["katara", ["soccerstadium.rel.txt"]] is done. Output size = 0
# Running ["katara", ["softballstadium.rel.txt"]] is done. Output size = 0
# Running ["katara", ["song.rel.txt"]] is done. Output size = 0
# Running ["katara", ["source.rel.txt"]] is done. Output size = 0
# Running ["katara", ["source1Country.rel.txt"]] is done. Output size = 0
# Running ["katara", ["source1Elevation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["source1ElevationImperial.rel.txt"]] is done. Output size = 0
# Running ["katara", ["available.rel.txt"]] is done. Output size = 0
# Running ["katara", ["averageSpeed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["avgClassSize.rel.txt"]] is done. Output size = 0
# Running ["katara", ["avgSpeed.rel.txt"]] is done. Output size = 4
# Running ["katara", ["award.rel.txt"]] is done. Output size = 0
# Running ["katara", ["awards.rel.txt"]] is done. Output size = 0
# Running ["katara", ["b.rel.txt"]] is done. Output size = 0
# Running ["katara", ["background.rel.txt"]] is done. Output size = 8
# Running ["katara", ["baggageCheck.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ball.rel.txt"]] is done. Output size = 0
# Running ["katara", ["ballpark.rel.txt"]] is done. Output size = 0
# Running ["katara", ["band.rel.txt"]] is done. Output size = 0
# Running ["katara", ["barPassRate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["baseballfield.rel.txt"]] is done. Output size = 0
# Running ["katara", ["based.rel.txt"]] is done. Output size = 0
# Running ["katara", ["basedOn.rel.txt"]] is done. Output size = 0
# Running ["katara", ["baseElevation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dateRest.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dates.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dateUse.rel.txt"]] is done. Output size = 0
# Running ["katara", ["day.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dean.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deathCause.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deathDate.rel.txt"]] is done. Output size = 4
# Running ["katara", ["deathdate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deathPlace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deathplace.rel.txt"]] is done. Output size = 0
# Running ["katara", ["debut.rel.txt"]] is done. Output size = 0
# Running ["katara", ["debutteam.rel.txt"]] is done. Output size = 0
# Running ["katara", ["debutyear.rel.txt"]] is done. Output size = 0
# Running ["katara", ["dec.rel.txt"]] is done. Output size = 0
# Running ["katara", ["decidedate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["decommissioned.rel.txt"]] is done. Output size = 0
# Running ["katara", ["defunct.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deliverydate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["demolished.rel.txt"]] is done. Output size = 0
# Running ["katara", ["demolitionDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["demonym.rel.txt"]] is done. Output size = 0
# Running ["katara", ["denomination.rel.txt"]] is done. Output size = 0
# Running ["katara", ["density.rel.txt"]] is done. Output size = 4
# Running ["katara", ["densityKm.rel.txt"]] is done. Output size = 0
# Running ["katara", ["densitySqMi.rel.txt"]] is done. Output size = 0
# Running ["katara", ["department.rel.txt"]] is done. Output size = 0
# Running ["katara", ["departments.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deployed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["depth.rel.txt"]] is done. Output size = 0
# Running ["katara", ["depthM.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deputy.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deputyHead.rel.txt"]] is done. Output size = 0
# Running ["katara", ["deputyHeadLabel.rel.txt"]] is done. Output size = 0
# Running ["katara", ["derivatives.rel.txt"]] is done. Output size = 0
# Running ["katara", ["followingevent.rel.txt"]] is done. Output size = 0
# Running ["katara", ["foodType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["format.rel.txt"]] is done. Output size = 3
# Running ["katara", ["formation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formed.rel.txt"]] is done. Output size = 0
# Running ["katara", ["former.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerAffiliations.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerCallsigns.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerChannelNumbers.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerchoreographer.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formercoach.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerNames.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerpartner.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerSchool(s)_.rel.txt"]] is done. Output size = 0
# Running ["katara", ["formerTeams.rel.txt"]] is done. Output size = 0
# Running ["katara", ["foundation.rel.txt"]] is done. Output size = 0
# Running ["katara", ["founded.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plantType.rel.txt"]] is done. Output size = 0
# Running ["katara", ["platform.rel.txt"]] is done. Output size = 0
# Running ["katara", ["platforms.rel.txt"]] is done. Output size = 0
# Running ["katara", ["playedFor.rel.txt"]] is done. Output size = 0
# Running ["katara", ["playername.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plays.rel.txt"]] is done. Output size = 0
# Running ["katara", ["plz.rel.txt"]] is done. Output size = 0
# Running ["katara", ["podiums.rel.txt"]] is done. Output size = 0
# Running ["katara", ["poleCountry.rel.txt"]] is done. Output size = 0
# Running ["katara", ["poleDriver.rel.txt"]] is done. Output size = 0
# Running ["katara", ["poles.rel.txt"]] is done. Output size = 0
# Running ["katara", ["poleTeam.rel.txt"]] is done. Output size = 0
# Running ["katara", ["politicalGroups.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pop.rel.txt"]] is done. Output size = 0
# Running ["katara", ["pop2010census.rel.txt"]] is done. Output size = 0
# Running ["katara", ["popDate.rel.txt"]] is done. Output size = 0
# Running ["katara", ["popEstAsOf.rel.txt"]] is done. Output size = 0
# Running ["katara", ["popMetro.rel.txt"]] is done. Output size = 0

# %% [markdown]
# ## 5. Feature Vector Generation

# %% [markdown]
# We then generate a feature vector for each data cell based on the output of error detection strategies.

# %%
application.feature_generator(d)
# Out:
# Extracting features for column 0...
# Extracting features for column 1...
# Extracting features for column 2...

# %% [markdown]
# ## 6. Interactive Error Detection

# %% [markdown]
# We then need to get involved to label data cells of those tuples that are sampled by Raha. Note that we can check the current state of the dataset (including the clean and dirty data cells) and finish the interactive process at will.

# %%
application.error_detector(d)
# Out:
# Building clustering model for column 0...
# Building clustering model for column 1...
# Building clustering model for column 2...
# Run 0...
# Label the dirty cells in the following sampled tuple.
#   ID     Lord Kingdom
# 2  3  Gandalf
# Is the value '3' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Gandalf' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value '' dirty?
# Type 1 for yes.
# Type 0 for no.
# 1
# <style  type="text/css" >
#     #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row0_col2 {
#             background-color:  red;
#         }    #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row1_col2 {
#             background-color:  red;
#         }    #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row2_col2 {
#             background-color:  red;
#         }    #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row3_col2 {
#             background-color:  red;
#         }    #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row4_col2 {
#             background-color:  red;
#         }    #T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row5_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Lord</th>
#         <th class="col_heading level0 col2" >Kingdom</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row0_col1" class="data row0 col1" >Aragorn</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row0_col2" class="data row0 col2" >Minas Tirith</td>
#     </tr>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row1_col1" class="data row1 col1" >Sauron</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row1_col2" class="data row1 col2" >Mordor</td>
#     </tr>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row2_col1" class="data row2 col1" >Gandalf</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row2_col2" class="data row2 col2" ></td>
#     </tr>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row3_col0" class="data row3 col0" >4</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row3_col1" class="data row3 col1" >Saruman</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row3_col2" class="data row3 col2" ></td>
#     </tr>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row4_col0" class="data row4 col0" >5</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row4_col1" class="data row4 col1" >Elrond</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row4_col2" class="data row4 col2" >123</td>
#     </tr>    <tr>
#         <th id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row5_col0" class="data row5 col0" >6</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row5_col1" class="data row5 col1" >Theoden</td>
#         <td id="T_e357a4f0_6110_11e9_8cd2_ccb0daadc333row5_col2" class="data row5 col2" >Shire</td>
#     </tr></tbody>
# </table>
# Would you like to label one more tuple?
# Type 1 for yes.
# Type 0 for no.
# 1
# Label the dirty cells in the following sampled tuple.
#   ID    Lord Kingdom
# 1  2  Sauron  Mordor
# Is the value '2' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Sauron' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Mordor' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# <style  type="text/css" >
#     #T_e7966f38_6110_11e9_8cd2_ccb0daadc333row2_col2 {
#             background-color:  red;
#         }    #T_e7966f38_6110_11e9_8cd2_ccb0daadc333row3_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Lord</th>
#         <th class="col_heading level0 col2" >Kingdom</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row0_col0" class="data row0 col0" >1</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row0_col1" class="data row0 col1" >Aragorn</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row0_col2" class="data row0 col2" >Minas Tirith</td>
#     </tr>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row1_col0" class="data row1 col0" >2</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row1_col1" class="data row1 col1" >Sauron</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row1_col2" class="data row1 col2" >Mordor</td>
#     </tr>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row2_col0" class="data row2 col0" >3</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row2_col1" class="data row2 col1" >Gandalf</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row2_col2" class="data row2 col2" ></td>
#     </tr>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row3_col0" class="data row3 col0" >4</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row3_col1" class="data row3 col1" >Saruman</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row3_col2" class="data row3 col2" ></td>
#     </tr>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row4_col0" class="data row4 col0" >5</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row4_col1" class="data row4 col1" >Elrond</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row4_col2" class="data row4 col2" >123</td>
#     </tr>    <tr>
#         <th id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row5_col0" class="data row5 col0" >6</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row5_col1" class="data row5 col1" >Theoden</td>
#         <td id="T_e7966f38_6110_11e9_8cd2_ccb0daadc333row5_col2" class="data row5 col2" >Shire</td>
#     </tr></tbody>
# </table>
# Would you like to label one more tuple?
# Type 1 for yes.
# Type 0 for no.
# 1
# Label the dirty cells in the following sampled tuple.
#   ID    Lord Kingdom
# 4  5  Elrond     123
# Is the value '5' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Elrond' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value '123' dirty?
# Type 1 for yes.
# Type 0 for no.
# 1
# <style  type="text/css" >
#     #T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row2_col2 {
#             background-color:  red;
#         }    #T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row3_col2 {
#             background-color:  red;
#         }    #T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row4_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Lord</th>
#         <th class="col_heading level0 col2" >Kingdom</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row0_col0" class="data row0 col0" >1</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row0_col1" class="data row0 col1" >Aragorn</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row0_col2" class="data row0 col2" >Minas Tirith</td>
#     </tr>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row1_col0" class="data row1 col0" >2</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row1_col1" class="data row1 col1" >Sauron</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row1_col2" class="data row1 col2" >Mordor</td>
#     </tr>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row2_col0" class="data row2 col0" >3</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row2_col1" class="data row2 col1" >Gandalf</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row2_col2" class="data row2 col2" ></td>
#     </tr>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row3_col0" class="data row3 col0" >4</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row3_col1" class="data row3 col1" >Saruman</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row3_col2" class="data row3 col2" ></td>
#     </tr>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row4_col0" class="data row4 col0" >5</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row4_col1" class="data row4 col1" >Elrond</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row4_col2" class="data row4 col2" >123</td>
#     </tr>    <tr>
#         <th id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row5_col0" class="data row5 col0" >6</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row5_col1" class="data row5 col1" >Theoden</td>
#         <td id="T_ebd3db26_6110_11e9_8cd2_ccb0daadc333row5_col2" class="data row5 col2" >Shire</td>
#     </tr></tbody>
# </table>
# Would you like to label one more tuple?
# Type 1 for yes.
# Type 0 for no.
# 1
# Label the dirty cells in the following sampled tuple.
#   ID     Lord Kingdom
# 3  4  Saruman
# Is the value '4' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Saruman' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value '' dirty?
# Type 1 for yes.
# Type 0 for no.
# 1
# <style  type="text/css" >
#     #T_f025c932_6110_11e9_8cd2_ccb0daadc333row2_col2 {
#             background-color:  red;
#         }    #T_f025c932_6110_11e9_8cd2_ccb0daadc333row3_col2 {
#             background-color:  red;
#         }    #T_f025c932_6110_11e9_8cd2_ccb0daadc333row4_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_f025c932_6110_11e9_8cd2_ccb0daadc333" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Lord</th>
#         <th class="col_heading level0 col2" >Kingdom</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row0_col0" class="data row0 col0" >1</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row0_col1" class="data row0 col1" >Aragorn</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row0_col2" class="data row0 col2" >Minas Tirith</td>
#     </tr>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row1_col0" class="data row1 col0" >2</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row1_col1" class="data row1 col1" >Sauron</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row1_col2" class="data row1 col2" >Mordor</td>
#     </tr>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row2_col0" class="data row2 col0" >3</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row2_col1" class="data row2 col1" >Gandalf</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row2_col2" class="data row2 col2" ></td>
#     </tr>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row3_col0" class="data row3 col0" >4</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row3_col1" class="data row3 col1" >Saruman</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row3_col2" class="data row3 col2" ></td>
#     </tr>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row4_col0" class="data row4 col0" >5</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row4_col1" class="data row4 col1" >Elrond</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row4_col2" class="data row4 col2" >123</td>
#     </tr>    <tr>
#         <th id="T_f025c932_6110_11e9_8cd2_ccb0daadc333level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row5_col0" class="data row5 col0" >6</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row5_col1" class="data row5 col1" >Theoden</td>
#         <td id="T_f025c932_6110_11e9_8cd2_ccb0daadc333row5_col2" class="data row5 col2" >Shire</td>
#     </tr></tbody>
# </table>
# Would you like to label one more tuple?
# Type 1 for yes.
# Type 0 for no.
# 1
# Label the dirty cells in the following sampled tuple.
#   ID     Lord Kingdom
# 5  6  Theoden   Shire
# Is the value '6' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Theoden' dirty?
# Type 1 for yes.
# Type 0 for no.
# 0
# Is the value 'Shire' dirty?
# Type 1 for yes.
# Type 0 for no.
# 1
# <style  type="text/css" >
#     #T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row2_col2 {
#             background-color:  red;
#         }    #T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row3_col2 {
#             background-color:  red;
#         }    #T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row4_col2 {
#             background-color:  red;
#         }    #T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row5_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ID</th>
#         <th class="col_heading level0 col1" >Lord</th>
#         <th class="col_heading level0 col2" >Kingdom</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row0_col0" class="data row0 col0" >1</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row0_col1" class="data row0 col1" >Aragorn</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row0_col2" class="data row0 col2" >Minas Tirith</td>
#     </tr>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row1_col0" class="data row1 col0" >2</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row1_col1" class="data row1 col1" >Sauron</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row1_col2" class="data row1 col2" >Mordor</td>
#     </tr>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row2_col0" class="data row2 col0" >3</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row2_col1" class="data row2 col1" >Gandalf</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row2_col2" class="data row2 col2" ></td>
#     </tr>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row3_col0" class="data row3 col0" >4</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row3_col1" class="data row3 col1" >Saruman</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row3_col2" class="data row3 col2" ></td>
#     </tr>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row4_col0" class="data row4 col0" >5</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row4_col1" class="data row4 col1" >Elrond</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row4_col2" class="data row4 col2" >123</td>
#     </tr>    <tr>
#         <th id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row5_col0" class="data row5 col0" >6</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row5_col1" class="data row5 col1" >Theoden</td>
#         <td id="T_00b97dd4_6111_11e9_8cd2_ccb0daadc333row5_col2" class="data row5 col2" >Shire</td>
#     </tr></tbody>
# </table>
# Would you like to label one more tuple?
# Type 1 for yes.
# Type 0 for no.
# 0
