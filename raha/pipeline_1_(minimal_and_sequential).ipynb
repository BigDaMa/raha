# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Sequential)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display

import raha

# %% [markdown]
# ## Error Detection with Raha

# %% [markdown]
# ### 1. Instantiating the Detection Class
# We first instantiate the `Detection` class.

# %%
app_1 = raha.Detection()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20

# Would you like to see the logs?
app_1.VERBOSE = True

# %% [markdown]
# ### 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
    "name": "flights",
    "path": "../datasets/flights/dirty.csv",
    "clean_path": "../datasets/flights/clean.csv"
}
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.  \
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %% [markdown]
# ### 3. Running Error Detection Strategies
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset.

# %%
app_1.run_strategies(d)
# Out:
# 7 cells are detected by ["PVD", ["sched_arr_time", "u"]].
# 602 cells are detected by ["PVD", ["act_dep_time", "4"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "v"]].
#
# 590 cells are detected by ["PVD", ["flight", "X"]].10 cells are detected by ["PVD", ["sched_dep_time", "/"]].162 cells are detected by ["PVD", ["flight", "G"]].
#
#
# 42 cells are detected by ["PVD", ["act_arr_time", "E"]].331 cells are detected by ["PVD", ["sched_dep_time", "4"]].
# 283 cells are detected by ["PVD", ["flight", "T"]].
# 791 cells are detected by ["PVD", ["sched_dep_time", "a"]].1716 cells are detected by ["PVD", ["src", "t"]].
#
# 1962 cells are detected by ["PVD", ["act_arr_time", ":"]].
# 85 cells are detected by ["PVD", ["sched_dep_time", "e"]].
# 1503 cells are detected by ["PVD", ["sched_dep_time", "."]].
# 547 cells are detected by ["PVD", ["flight", "7"]].
# 14 cells are detected by ["PVD", ["act_dep_time", "C"]].
# 436 cells are detected by ["PVD", ["src", "c"]].
# 15 cells are detected by ["PVD", ["sched_dep_time", "o"]].4 cells are detected by ["PVD", ["sched_dep_time", "-"]].
#
# 1540 cells are detected by ["PVD", ["flight", "O"]].
# 1 cells are detected by ["PVD", ["act_arr_time", "\u00a0"]].
# 2376 cells are detected by ["PVD", ["flight", "-"]].
# 38 cells are detected by ["PVD", ["act_dep_time", "r"]].
# 24 cells are detected by ["PVD", ["act_dep_time", "w"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "T"]].
# 196 cells are detected by ["PVD", ["sched_dep_time", "6"]].
# 956 cells are detected by ["PVD", ["act_arr_time", "1"]].
# 397 cells are detected by ["PVD", ["flight", "E"]].13 cells are detected by ["PVD", ["sched_arr_time", "b"]].
#
# 871 cells are detected by ["PVD", ["flight", "4"]].
# 4 cells are detected by ["PVD", ["sched_dep_time", "("]].
# 36 cells are detected by ["PVD", ["act_arr_time", "u"]].
# 75 cells are detected by ["PVD", ["act_dep_time", "D"]].
# 39 cells are detected by ["PVD", ["flight", "Y"]].
# 470 cells are detected by ["PVD", ["act_arr_time", "9"]].
# 264 cells are detected by ["PVD", ["sched_arr_time", "9"]].729 cells are detected by ["PVD", ["sched_arr_time", "1"]].
#
# 48 cells are detected by ["PVD", ["act_arr_time", ")"]].409 cells are detected by ["PVD", ["sched_dep_time", "2"]].
#
# 1375 cells are detected by ["PVD", ["src", "l"]].1518 cells are detected by ["PVD", ["src", "i"]].
#
# 20 cells are detected by ["PVD", ["sched_arr_time", "-"]].
# 885 cells are detected by ["PVD", ["sched_arr_time", "5"]].13 cells are detected by ["PVD", ["sched_dep_time", "A"]].
#
# 676 cells are detected by ["PVD", ["act_arr_time", "3"]].
# 828 cells are detected by ["PVD", ["flight", "L"]].
# 229 cells are detected by ["PVD", ["sched_arr_time", "7"]].
#
# 8 cells are detected by ["PVD", ["act_arr_time", "/"]].64 cells are detected by ["PVD", ["act_dep_time", "i"]].
# 44 cells are detected by ["PVD", ["act_arr_time", "n"]].
# 638 cells are detected by ["PVD", ["act_arr_time", "2"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "i"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "v"]].
# 226 cells are detected by ["PVD", ["sched_arr_time", "6"]].
# 263 cells are detected by ["PVD", ["src", "x"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "l"]].
# 764 cells are detected by ["PVD", ["act_dep_time", "2"]].
# 539 cells are detected by ["PVD", ["flight", "0"]].
# 821 cells are detected by ["PVD", ["sched_dep_time", "5"]].
#
# 3836 cells are detected by ["RVD", ["act_dep_time", "src"]].1503 cells are detected by ["PVD", ["sched_dep_time", "m"]].
# 677 cells are detected by ["PVD", ["flight", "8"]].
# 99 cells are detected by ["PVD", ["src", "z"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "N"]].745 cells are detected by ["PVD", ["src", "h"]].
#
# 1020 cells are detected by ["PVD", ["src", "g"]].
# 627 cells are detected by ["PVD", ["sched_arr_time", "a"]].30 cells are detected by ["PVD", ["act_arr_time", "w"]].
#
# 437 cells are detected by ["PVD", ["sched_arr_time", "4"]].
# 117 cells are detected by ["PVD", ["sched_arr_time", "c"]].
# 1172 cells are detected by ["RVD", ["sched_arr_time", "sched_dep_time"]].
# 131 cells are detected by ["PVD", ["sched_dep_time", "9"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "/"]].
# 16 cells are detected by ["PVD", ["sched_arr_time", "A"]].
# 163 cells are detected by ["PVD", ["flight", "N"]].
# 2 cells are detected by ["PVD", ["sched_arr_time", "P"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "o"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "d"]].
# 616 cells are detected by ["PVD", ["tuple_id", "4"]].
#
# 606 cells are detected by ["PVD", ["tuple_id", "9"]].7 cells are detected by ["PVD", ["sched_arr_time", "h"]].821 cells are detected by ["PVD", ["src", "n"]].
# 952 cells are detected by ["PVD", ["flight", "I"]].
# 2 cells are detected by ["PVD", ["sched_dep_time", "n"]].
#
# 17 cells are detected by ["PVD", ["sched_arr_time", "F"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "v"]].
# 74 cells are detected by ["PVD", ["act_arr_time", "t"]].
# 0 cells are detected by ["RVD", ["tuple_id", "sched_arr_time"]].
# 542 cells are detected by ["PVD", ["src", "u"]].405 cells are detected by ["PVD", ["act_arr_time", "6"]].
#
# 29 cells are detected by ["PVD", ["act_dep_time", "y"]].
# 539 cells are detected by ["PVD", ["src", "v"]].
# 36 cells are detected by ["PVD", ["act_dep_time", "d"]].
# 2 cells are detected by ["PVD", ["act_arr_time", "*"]].905 cells are detected by ["PVD", ["flight", "3"]].
#
# 19 cells are detected by ["PVD", ["src", "C"]].
# 2329 cells are detected by ["PVD", ["flight", "A"]].
# 1205 cells are detected by ["PVD", ["src", "o"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "t"]].
# 451 cells are detected by ["PVD", ["sched_arr_time", "3"]].
# 473 cells are detected by ["PVD", ["act_dep_time", "8"]].
# 603 cells are detected by ["PVD", ["act_arr_time", "5"]].
# 263 cells are detected by ["PVD", ["src", "m"]].
# 1635 cells are detected by ["KBVD", "/home/speckmann/raha/raha/tools/KATARA/knowledge-base/zipHasCity.rel.txt"].
# 805 cells are detected by ["PVD", ["act_arr_time", "a"]].
# 279 cells are detected by ["PVD", ["flight", "J"]].
# 43 cells are detected by ["PVD", ["act_arr_time", "r"]].
# 1106 cells are detected by ["PVD", ["flight", "D"]].
# 628 cells are detected by ["PVD", ["flight", "6"]].
# 84 cells are detected by ["PVD", ["act_dep_time", "c"]].
# 106 cells are detected by ["PVD", ["sched_arr_time", "8"]].
# 1589 cells are detected by ["PVD", ["sched_dep_time", " "]].
# 1426 cells are detected by ["PVD", ["tuple_id", "1"]].
# 2728 cells are detected by ["RVD", ["sched_dep_time", "sched_arr_time"]].32 cells are detected by ["PVD", ["act_dep_time", "A"]].
#
# 506 cells are detected by ["PVD", ["flight", "S"]].
# 620 cells are detected by ["PVD", ["src", "y"]].
#
# 741 cells are detected by ["PVD", ["sched_arr_time", "0"]].31 cells are detected by ["PVD", ["act_dep_time", "s"]].
# 495 cells are detected by ["PVD", ["flight", "9"]].
# 24 cells are detected by ["PVD", ["act_dep_time", "u"]].72 cells are detected by ["PVD", ["sched_dep_time", "D"]].
#
# 4662 cells are detected by ["RVD", ["src", "act_arr_time"]].
# 1304 cells are detected by ["RVD", ["act_arr_time", "sched_dep_time"]].42 cells are detected by ["PVD", ["act_arr_time", "s"]].527 cells are detected by ["PVD", ["sched_arr_time", "2"]].
#
#
# 23 cells are detected by ["PVD", ["sched_arr_time", "/"]].
# 174 cells are detected by ["PVD", ["sched_dep_time", "8"]].32 cells are detected by ["PVD", ["act_arr_time", "o"]].
#
# 7 cells are detected by ["PVD", ["sched_arr_time", "T"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "h"]].
# 32 cells are detected by ["PVD", ["act_arr_time", "l"]].
# 0 cells are detected by ["RVD", ["tuple_id", "flight"]].
# 35 cells are detected by ["PVD", ["act_dep_time", "("]].1968 cells are detected by ["PVD", ["act_dep_time", ":"]].
#
# 659 cells are detected by ["PVD", ["act_arr_time", "0"]].399 cells are detected by ["PVD", ["src", "w"]].
# 63 cells are detected by ["PVD", ["act_dep_time", "t"]].
#
# 732 cells are detected by ["PVD", ["flight", "F"]].
# 1141 cells are detected by ["PVD", ["src", "r"]].
# 1101 cells are detected by ["PVD", ["src", "f"]].
# 0 cells are detected by ["RVD", ["tuple_id", "act_arr_time"]].671 cells are detected by ["PVD", ["src", "s"]].
# 1999 cells are detected by ["PVD", ["act_dep_time", " "]].
#
# 100 cells are detected by ["PVD", ["src", "j"]].
# 2978 cells are detected by ["RVD", ["act_dep_time", "act_arr_time"]].919 cells are detected by ["PVD", ["tuple_id", "2"]].796 cells are detected by ["PVD", ["flight", "1"]].
#
#
# 3834 cells are detected by ["RVD", ["act_arr_time", "src"]].1118 cells are detected by ["PVD", ["act_dep_time", "a"]].
#
# 32 cells are detected by ["PVD", ["act_dep_time", "o"]].
# 476 cells are detected by ["PVD", ["act_dep_time", "7"]].
# 1606 cells are detected by ["PVD", ["sched_arr_time", " "]].
# 76 cells are detected by ["PVD", ["act_arr_time", "i"]].
# 4752 cells are detected by ["RVD", ["flight", "act_dep_time"]].
# 55 cells are detected by ["PVD", ["src", "-"]].
# 117 cells are detected by ["PVD", ["sched_arr_time", "D"]].
# 352 cells are detected by ["PVD", ["sched_dep_time", "3"]].
# 811 cells are detected by ["PVD", ["flight", "2"]].
# 220 cells are detected by ["PVD", ["act_arr_time", "8"]].
# 6 cells are detected by ["PVD", ["act_arr_time", "T"]].4740 cells are detected by ["RVD", ["src", "sched_arr_time"]].
#
# 770 cells are detected by ["PVD", ["sched_dep_time", "1"]].
# 1910 cells are detected by ["PVD", ["act_arr_time", "m"]].
# 39 cells are detected by ["PVD", ["act_dep_time", "n"]].889 cells are detected by ["PVD", ["sched_dep_time", "0"]].
#
# 676 cells are detected by ["PVD", ["tuple_id", "3"]].
# 2682 cells are detected by ["RVD", ["act_arr_time", "act_dep_time"]].1082 cells are detected by ["RVD", ["act_dep_time", "sched_dep_time"]].
# 1525 cells are detected by ["PVD", ["sched_arr_time", "m"]].
#
# 17 cells are detected by ["PVD", ["sched_arr_time", "r"]].1940 cells are detected by ["RVD", ["act_dep_time", "sched_arr_time"]].13 cells are detected by ["PVD", ["sched_arr_time", "N"]].
#
# 13 cells are detected by ["PVD", ["sched_arr_time", "l"]].
#
# 13 cells are detected by ["PVD", ["sched_arr_time", "t"]].
# 35 cells are detected by ["PVD", ["act_dep_time", ")"]].
# 0 cells are detected by ["RVD", ["tuple_id", "sched_dep_time"]].348 cells are detected by ["PVD", ["act_arr_time", "7"]].
#
# 1393 cells are detected by ["PVD", ["src", "e"]].
# 30 cells are detected by ["PVD", ["act_arr_time", "y"]].
# 31 cells are detected by ["PVD", ["act_dep_time", "E"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "N"]].
# 606 cells are detected by ["PVD", ["tuple_id", "0"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "T"]].
# 2836 cells are detected by ["RVD", ["sched_dep_time", "act_dep_time"]].
# 1897 cells are detected by ["PVD", ["act_dep_time", "."]].
# 2144 cells are detected by ["RVD", ["sched_arr_time", "act_arr_time"]].
# 2 cells are detected by ["PVD", ["act_arr_time", "P"]].797 cells are detected by ["PVD", ["sched_dep_time", "p"]].
#
# 331 cells are detected by ["PVD", ["sched_dep_time", "7"]].
# 117 cells are detected by ["PVD", ["act_arr_time", "e"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "b"]].
# 907 cells are detected by ["PVD", ["flight", "R"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "O"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "b"]].
# 0 cells are detected by ["RVD", ["tuple_id", "src"]].
# 0 cells are detected by ["RVD", ["tuple_id", "act_dep_time"]].
# 399 cells are detected by ["PVD", ["src", "b"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "u"]].
# 1593 cells are detected by ["PVD", ["sched_arr_time", ":"]].
# 4 cells are detected by ["PVD", ["sched_dep_time", ")"]].
# 689 cells are detected by ["PVD", ["flight", "U"]].
#
# 4750 cells are detected by ["RVD", ["src", "flight"]].606 cells are detected by ["PVD", ["tuple_id", "8"]].
# 669 cells are detected by ["PVD", ["flight", "5"]].
# 1989 cells are detected by ["PVD", ["act_arr_time", " "]].
# 14 cells are detected by ["PVD", ["act_arr_time", "C"]].
# 259 cells are detected by ["PVD", ["src", "d"]].
# 1897 cells are detected by ["PVD", ["act_dep_time", "m"]].912 cells are detected by ["PVD", ["act_dep_time", "p"]].
# 1579 cells are detected by ["PVD", ["sched_dep_time", ":"]].
# 37 cells are detected by ["PVD", ["act_dep_time", "l"]].
#
# 279 cells are detected by ["PVD", ["flight", "K"]].
# 1910 cells are detected by ["PVD", ["act_arr_time", "."]].
# 616 cells are detected by ["PVD", ["tuple_id", "5"]].
# 72 cells are detected by ["PVD", ["sched_dep_time", "c"]].
# 30 cells are detected by ["PVD", ["sched_arr_time", "i"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "b"]].1132 cells are detected by ["RVD", ["act_arr_time", "sched_arr_time"]].
#
# 2 cells are detected by ["PVD", ["act_arr_time", "F"]].
#
# 147 cells are detected by ["PVD", ["src", "k"]].
# 48 cells are detected by ["PVD", ["act_arr_time", "("]].1525 cells are detected by ["PVD", ["sched_arr_time", "."]].
# 61 cells are detected by ["PVD", ["act_arr_time", "c"]].92 cells are detected by ["PVD", ["src", "q"]].
#
# 3112 cells are detected by ["RVD", ["sched_arr_time", "tuple_id"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "v"]].967 cells are detected by ["PVD", ["sched_arr_time", "p"]].
#
# 874 cells are detected by ["PVD", ["flight", "H"]].
# 1209 cells are detected by ["PVD", ["act_arr_time", "p"]].950 cells are detected by ["PVD", ["flight", "C"]].
# 86 cells are detected by ["PVD", ["flight", "B"]].
#
# 35 cells are detected by ["PVD", ["act_arr_time", "A"]].
# 139 cells are detected by ["PVD", ["act_dep_time", "e"]].
# 637 cells are detected by ["PVD", ["act_dep_time", "0"]].
# 1550 cells are detected by ["RVD", ["act_dep_time", "flight"]].
# 498 cells are detected by ["PVD", ["flight", "P"]].
# 964 cells are detected by ["RVD", ["act_arr_time", "flight"]].
# 3852 cells are detected by ["RVD", ["act_dep_time", "tuple_id"]].
# 4636 cells are detected by ["RVD", ["src", "act_dep_time"]].
# 6 cells are detected by ["PVD", ["act_arr_time", "h"]].
# 4752 cells are detected by ["RVD", ["flight", "tuple_id"]].
# 3108 cells are detected by ["RVD", ["sched_arr_time", "src"]].
# 4704 cells are detected by ["RVD", ["src", "sched_dep_time"]].
# 591 cells are detected by ["PVD", ["act_arr_time", "4"]].
# 1110 cells are detected by ["RVD", ["sched_dep_time", "flight"]].
# 709 cells are detected by ["PVD", ["flight", "M"]].
# 2378 cells are detected by ["RVD", ["sched_arr_time", "act_dep_time"]].
# 4210 cells are detected by ["RVD", ["flight", "sched_arr_time"]].
# 3838 cells are detected by ["RVD", ["act_arr_time", "tuple_id"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "N"]].
# 670 cells are detected by ["RVD", ["sched_arr_time", "flight"]].
# 3 cells are detected by ["PVD", ["act_arr_time", "R"]].
# 3232 cells are detected by ["RVD", ["flight", "sched_dep_time"]].
# 4750 cells are detected by ["RVD", ["src", "tuple_id"]].
# 3116 cells are detected by ["RVD", ["sched_dep_time", "tuple_id"]].
# 508 cells are detected by ["PVD", ["act_dep_time", "3"]].
# 4752 cells are detected by ["RVD", ["flight", "src"]].
# 357 cells are detected by ["OD", ["gaussian", "2.5"]].
# 383 cells are detected by ["PVD", ["act_dep_time", "6"]].
# 1333 cells are detected by ["OD", ["gaussian", "2.0"]].
# 3585 cells are detected by ["OD", ["gaussian", "1.3"]].
# 3904 cells are detected by ["OD", ["gaussian", "1.0"]].
# 145 cells are detected by ["PVD", ["flight", "V"]].
# 668 cells are detected by ["OD", ["histogram", "0.9", "0.1"]].
# 794 cells are detected by ["OD", ["gaussian", "2.3"]].
# 19 cells are detected by ["PVD", ["src", "O"]].
# 1849 cells are detected by ["OD", ["gaussian", "1.7"]].
# 6724 cells are detected by ["OD", ["histogram", "0.1", "0.3"]].
# 12412 cells are detected by ["OD", ["histogram", "0.7", "0.7"]].
# 8189 cells are detected by ["OD", ["histogram", "0.9", "0.5"]].
# 9644 cells are detected by ["OD", ["histogram", "0.7", "0.5"]].
# 562 cells are detected by ["PVD", ["act_dep_time", "5"]].
# 12001 cells are detected by ["OD", ["histogram", "0.3", "0.5"]].
# 616 cells are detected by ["PVD", ["tuple_id", "6"]].
# 693 cells are detected by ["OD", ["histogram", "0.5", "0.1"]].1922 cells are detected by ["OD", ["gaussian", "1.5"]].
#
# 409 cells are detected by ["PVD", ["src", "p"]].
# 14275 cells are detected by ["OD", ["histogram", "0.5", "0.9"]].
# 130 cells are detected by ["PVD", ["sched_arr_time", "e"]].
# 248 cells are detected by ["OD", ["gaussian", "3.0"]].
# 4 cells are detected by ["PVD", ["act_dep_time", "+"]].9644 cells are detected by ["OD", ["histogram", "0.5", "0.5"]].
#
# 955 cells are detected by ["PVD", ["act_dep_time", "1"]].
# 2238 cells are detected by ["OD", ["histogram", "0.1", "0.1"]].
# 2830 cells are detected by ["RVD", ["sched_dep_time", "act_arr_time"]].
# 2934 cells are detected by ["OD", ["histogram", "0.9", "0.3"]].
# 14275 cells are detected by ["OD", ["histogram", "0.7", "0.9"]].
# 3098 cells are detected by ["RVD", ["sched_dep_time", "src"]].
# 557 cells are detected by ["PVD", ["flight", "W"]].
# 16632 cells are detected by ["OD", ["histogram", "0.1", "0.9"]].4367 cells are detected by ["OD", ["histogram", "0.7", "0.3"]].
#
# 613 cells are detected by ["PVD", ["tuple_id", "7"]].48 cells are detected by ["PVD", ["act_arr_time", "D"]].
#
# 2238 cells are detected by ["OD", ["histogram", "0.3", "0.1"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.9"]].
# 1129 cells are detected by ["PVD", ["src", "a"]].
# 12001 cells are detected by ["OD", ["histogram", "0.1", "0.5"]].
# 16632 cells are detected by ["OD", ["histogram", "0.3", "0.9"]].
# 258 cells are detected by ["PVD", ["act_dep_time", "9"]].
# 4367 cells are detected by ["OD", ["histogram", "0.5", "0.3"]].
# 4752 cells are detected by ["RVD", ["flight", "act_arr_time"]].
# 12412 cells are detected by ["OD", ["histogram", "0.5", "0.7"]].
# 6724 cells are detected by ["OD", ["histogram", "0.3", "0.3"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.7"]].
# 14769 cells are detected by ["OD", ["histogram", "0.1", "0.7"]].
# 14769 cells are detected by ["OD", ["histogram", "0.3", "0.7"]].
# 693 cells are detected by ["OD", ["histogram", "0.7", "0.1"]].
# 258 cells are detected by ["OD", ["gaussian", "2.7"]].
# 309 strategy profiles are collected.

# %% [markdown]
# ### 4. Generating Features
# Raha then generates a feature vector for each data cell based on the output of error detection strategies.

# %%
app_1.generate_features(d)
# Out:
# 40 Features are generated for column 0.
# 65 Features are generated for column 1.
# 62 Features are generated for column 2.
# 65 Features are generated for column 3.
# 71 Features are generated for column 4.
# 65 Features are generated for column 5.
# 86 Features are generated for column 6.

# %% [markdown]
# ### 5. Building Clusters
# Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.build_clusters(d)
# Out:
# A hierarchical clustering model is built for column 0.
# A hierarchical clustering model is built for column 1.
# A hierarchical clustering model is built for column 2.
# A hierarchical clustering model is built for column 3.
# A hierarchical clustering model is built for column 4.
# A hierarchical clustering model is built for column 5.
# A hierarchical clustering model is built for column 6.

# %% [markdown]
# ### 6. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)
    else:
        print("Label the dirty cells in the following sampled tuple.")
        sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
        IPython.display.display(sampled_tuple)
        for j in range(d.dataframe.shape[1]):
            cell = (d.sampled_tuple, j)
            value = d.dataframe.iloc[cell]
            correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
            user_label = 1 if value != correction else 0
            d.labeled_cells[cell] = [user_label, correction]
        d.labeled_tuples[d.sampled_tuple] = 1
# Out:
# Tuple 1234 is sampled.
# Tuple 1234 is labeled.
# Tuple 1385 is sampled.
# Tuple 1385 is labeled.
# Tuple 179 is sampled.
# Tuple 179 is labeled.
# Tuple 816 is sampled.
# Tuple 816 is labeled.
# Tuple 2358 is sampled.
# Tuple 2358 is labeled.
# Tuple 476 is sampled.
# Tuple 476 is labeled.
# Tuple 1415 is sampled.
# Tuple 1415 is labeled.
# Tuple 989 is sampled.
# Tuple 989 is labeled.
# Tuple 610 is sampled.
# Tuple 610 is labeled.
# Tuple 1304 is sampled.
# Tuple 1304 is labeled.
# Tuple 1973 is sampled.
# Tuple 1973 is labeled.
# Tuple 1874 is sampled.
# Tuple 1874 is labeled.
# Tuple 1126 is sampled.
# Tuple 1126 is labeled.
# Tuple 1789 is sampled.
# Tuple 1789 is labeled.
# Tuple 1672 is sampled.
# Tuple 1672 is labeled.
# Tuple 796 is sampled.
# Tuple 796 is labeled.
# Tuple 821 is sampled.
# Tuple 821 is labeled.
# Tuple 2192 is sampled.
# Tuple 2192 is labeled.
# Tuple 294 is sampled.
# Tuple 294 is labeled.
# Tuple 1965 is sampled.
# Tuple 1965 is labeled.

# %% [markdown]
# ### 7. Propagating User Labels
# Raha then propagates each user label through its cluster.

# %%
app_1.propagate_labels(d)
# Out:
# The number of labeled data cells increased from 140 to 12801.

# %% [markdown]
# ### 8. Predicting Labels of Data Cells
# Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.predict_labels(d)
# Out:
# A classifier is trained and applied on column 0.
# A classifier is trained and applied on column 1.
# A classifier is trained and applied on column 2.
# A classifier is trained and applied on column 3.
# A classifier is trained and applied on column 4.
# A classifier is trained and applied on column 5.
# A classifier is trained and applied on column 6.

# %% [markdown]
# ### 9. Storing Results
# Raha can also store the error detection results.

# %%
app_1.store_results(d)
# Out:
# The results are stored in ../datasets/flights/raha-baran-results-flights/error-detection/detection.dataset.

# %% [markdown]
# ### 10. Evaluating the Error Detection Task
# We can finally evaluate our error detection task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
print("Raha's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Raha's performance on flights:
# Precision = 0.81
# Recall = 0.91
# F1 = 0.86

# %% [markdown]
# # Error Correction with Baran

# %% [markdown]
# ### 1. Instantiating the Correction Class
# We first instantiate the `Correction` class.

# %%
app_2 = raha.Correction()

# How many tuples would you label?
app_2.LABELING_BUDGET = 20

# Would you like to see the logs?
app_2.VERBOSE = True

# %% [markdown]
# ### 2. Initializing the Dataset Object
# We next initialize the dataset object.

# %%
d = app_2.initialize_dataset(d)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.  \
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %% [markdown]
# ### 3. Initializing the Error Corrector Models
# Baran initializes the error corrector models.

# %%
app_2.initialize_models(d)
# Out:
# The error corrector models are initialized.

# %% [markdown]
# ### 4. Interactive Tuple Sampling, Labeling, Model updating, Feature Generation, and Correction Prediction
# Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
# while len(d.labeled_tuples) < app_2.LABELING_BUDGET:
#     app_2.sample_tuple(d)
#     if d.has_ground_truth:
#         app_2.label_with_ground_truth(d)
#     else:
#         print("Label the dirty cells in the following sampled tuple.")
#         sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
#         IPython.display.display(sampled_tuple)
#         for j in range(d.dataframe.shape[1]):
#             cell = (d.sampled_tuple, j)
#             value = d.dataframe.iloc[cell]
#             correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
#             user_label = 1 if value != correction else 0
#             d.labeled_cells[cell] = [user_label, correction]
#         d.labeled_tuples[d.sampled_tuple] = 1
#     app_2.update_models(d)
#     app_2.predict_corrections(d)

for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.predict_corrections(d)
# Out:
# The error corrector models are updated with new labeled tuple 1234.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 767 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 220 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1351 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1141 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 45% (2476 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1385.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 777 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 245 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1353 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1158 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 46% (2526 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 179.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 784 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 292 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1363 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1195 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 49% (2738 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 816.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 297 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1369 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1208 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 50% (2791 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2358.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 299 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1369 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1223 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 51% (2817 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 476.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 318 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1369 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1225 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 51% (2817 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1415.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 335 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1370 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1225 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 51% (2817 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 989.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 357 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1372 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1231 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 51% (2817 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 610.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 798 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 357 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1372 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1246 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 51% (2840 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1304.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 805 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 394 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1381 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1275 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2873 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1973.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 812 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 423 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1383 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1298 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2893 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1874.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 812 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 423 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1383 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1298 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2893 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1126.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 812 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 442 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1383 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1299 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2893 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1789.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 812 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 442 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1383 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1301 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2900 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1672.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 812 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 484 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1385 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1312 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 52% (2901 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 796.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 819 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 501 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1393 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1320 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 54% (2979 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 821.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 826 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 523 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1399 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1337 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 54% (2998 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2192.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 833 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 555 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1401 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1351 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 54% (2998 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 294.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 847 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 577 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1413 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1355 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 54% (2998 / 5535) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1965.
# Predicting module...
# ------------------------------------------------------------------------
# 1/4 columns(sched_dep_time)
# Generating train features(8) ...
# 854 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 2/4 columns(act_dep_time)
# Generating train features(17) ...
# 607 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 3/4 columns(sched_arr_time)
# Generating train features(10) ...
# 1413 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# ------------------------------------------------------------------------
# 4/4 columns(act_arr_time)
# Generating train features(13) ...
# 1360 pairs of (a data error, a potential correction) are featurized.
# Training classifier ...
# Predicting corrections...
# 54% (2998 / 5535) of data errors are corrected.

# %% [markdown]
# ### 5. Storing Results
# Baran can also store the error correction results.

# %%
app_2.store_results(d)
# Out:
# The results are stored in ../datasets/flights/raha-baran-results-flights/error-correction/correction.dataset.

# %% [markdown]
# ### 6. Evaluating the Error Correction Task
# We can finally evaluate our error correction task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]
print("Baran's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Baran's performance on flights:
# Precision = 0.88
# Recall = 0.53
# F1 = 0.66
